# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarkumarmishra/Data-Analysis-using-Python/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/content/SPORTS INFRASTRUCTURE UNDER GIS SYSTEM. (1).xlsx','Sheet2',skiprows=1)
df= pd.read_excel('/content/district.xlsx')

# %%
k = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 12 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Sl. No.                                                                                         171 non-null    float64
#  1   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  171 non-null    object
#  2   Size/ details of Infrastructure                                                                 168 non-null    object
#  3   Unnamed: 3                                                                                      156 non-null    object
#  4   Unnamed: 4                                                                                      138 non-null    object
# ...

# %%
smr = ['Built under Scheme','Sl. No.','Unnamed: 3','Unnamed: 4','Owned by Institution (State Govt./ SAI/Private)','Unnamed: 5','Unnamed: 10','Unnamed: 11','Size/ details of Infrastructure','Unnamed: 9']

# %%
sat = data.drop(smr,inplace =True,axis =1)

# %%
data.rename(columns={'Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)' : 'Name'}, inplace=True)

# %%
data.rename(columns={"Location of the Infrastructure (Tehsil/ Taluk and District)":"Address_line_1"}, inplace = True)

# %%
data.insert(loc=2, column= 'district_id',  value='0',  allow_duplicates=True)

# %%
data.insert(loc=3, column= 'manager_contact_no',  value='01123384782',  allow_duplicates=True)
data.insert(loc=4, column= 'state_id',  value='15',  allow_duplicates=True)
data.insert(loc=5, column= 'sub_ownership_id',  value='Karnataka',  allow_duplicates=True)
data.insert(loc=6, column= 'name_of_manager',  value='Shri Anurag Singh Thakur',  allow_duplicates=True)

# %%
data.head()
# Out:
#                          Name              Address_line_1 district_id  \
# 0                         NaN                         NaN           0
# 1     Sri Kanteerava Stadium                    Bangalore           0
# 2  Koramangala Indoor Stadium                   Bangalore           0
# 3                Vidyanagara                    Bangalore           0
# 4                      Anekal  Bangalore Urban District.            0
#
#   manager_contact_no state_id sub_ownership_id           name_of_manager
# 0        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 1        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 2        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 3        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 4        01123384782       15        Karnataka  Shri Anurag Singh Thakur

# %%
Pincode = pd.read_excel('/content/pin_code.xlsx')

# %%
create =['id','district_id']

# %%
new = Pincode.drop(create, axis =1, inplace =True)

# %%
Pincode.head()
# Out:
#    pincode
# 0   744201
# 1   744202
# 2   744302
# 3   744303
# 4   744105

# %%
data =pd.concat([data, Pincode], axis=1)

# %%
data.head(20)
# Out:
#                                        Name               Address_line_1  \
# 0                                       NaN                          NaN
# 1                   Sri Kanteerava Stadium                     Bangalore
# 2                Koramangala Indoor Stadium                    Bangalore
# 3                              Vidyanagara                     Bangalore
# 4                                    Anekal   Bangalore Urban District.
# 5                   Honnigaanahatti (South)   Bangalore Urban District.
# 6               Devarajeevanahallii (North)   Bangalore Urban District.
# 7            Yalahanka Taluk Ravutanahallia   Bangalore Urban District.
# 8                                Kumbalgodu   Bangalore Urban District.
# 9                                J.P. Nagar   Bangalore Urban District.
# 10                              Devanahalli           Devenahalli Taluk,
# 11                           Doddaballapura        Doddaballapura Taluk.
# ...

# %%
n = df.iloc[262:291]

# %%
n.drop('state_id',axis =1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
['Dakshina', 'Kannada', 'Hassan', 'Davangere','Kalaburagi','Kodagu','Chikkamagaluru','Chitradurga','Mysuru','Belagavi','Chamarajanagara','Ramanagara','Bengaluru Urban',
'Bengaluru Rural','Gadag','Ballari','Dharwad','Bagalkote','Yadgir','Shivamogga','Vijayapura','Koppal','Udupi','Mandya','Uttara Kannada','Kolar','Tumakuru','Raichur','Haveri','Chikkaballapura' ]
# Out:
# ['Dakshina',
#  'Kannada',
#  'Hassan',
#  'Davangere',
#  'Kalaburagi',
#  'Kodagu',
#  'Chikkamagaluru',
#  'Chitradurga',
#  'Mysuru',
#  'Belagavi',
#  'Chamarajanagara',
#  'Ramanagara',
#  'Bengaluru Urban',
#  'Bengaluru Rural',
#  'Gadag',
#  'Ballari',
#  'Dharwad',
#  'Bagalkote',
#  'Yadgir',
#  'Shivamogga',
#  'Vijayapura',
#  'Koppal',
#  'Udupi',
#  'Mandya',
#  'Uttara Kannada',
#  'Kolar',
#  'Tumakuru',
#  'Raichur',
#  'Haveri',
#  'Chikkaballapura']

# %%
k = pd.concat([data,df.iloc[262:291]],axis =1)

# %%
k.head()
# Out:
#                          Name              Address_line_1 district_id  \
# 0                         NaN                         NaN           0
# 1     Sri Kanteerava Stadium                    Bangalore           0
# 2  Koramangala Indoor Stadium                   Bangalore           0
# 3                Vidyanagara                    Bangalore           0
# 4                      Anekal  Bangalore Urban District.            0
#
#   manager_contact_no state_id sub_ownership_id           name_of_manager  \
# 0        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 1        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 2        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 3        01123384782       15        Karnataka  Shri Anurag Singh Thakur
# 4        01123384782       15        Karnataka  Shri Anurag Singh Thakur
#
#    pincode  id state_id district_name
# 0   744201 NaN      NaN           NaN
# ...
