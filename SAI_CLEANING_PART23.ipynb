# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarkumarmishra/Data-Analysis-using-Python/blob/main/SAI_CLEANING_PART23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/content/SPORTS INFRASTRUCTURE UNDER GIS SYSTEM. (1).xlsx','Sheet2',skiprows=1)

# %%
data.head()
# Out:
#    Sl. No.  \
# 0      NaN
# 1      1.0
# 2      2.0
# 3      3.0
# 4      4.0
#
#   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 0                                                NaN
# 1                            Sri Kanteerava Stadium
# 2                         Koramangala Indoor Stadium
# 3                                       Vidyanagara
# 4                                             Anekal
#
#   Size/ details of Infrastructure                       Unnamed: 3  \
# 0                   Size in Acres                       Survey No.
# 1                     29.36 Acres                    S. No. 193/P1
# 2                      4.16 Acres       S. No. 111, 112, 114, 115,
# 3                     62.00 Acres  S. No. 317, 317/1, 325/1, 325/2
# 4                    10.00  Acres                              248
#
#                                           Unnamed: 4  \
# 0  ¥ÁægÀA¨sÀªÁzÀ ªÀµÀð ªÀÄvÀÄÛ MlÄÖ ªÉZÀÑ (gÀÆ. ®...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 12 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Sl. No.                                                                                         171 non-null    float64
#  1   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  171 non-null    object
#  2   Size/ details of Infrastructure                                                                 168 non-null    object
#  3   Unnamed: 3                                                                                      156 non-null    object
#  4   Unnamed: 4                                                                                      138 non-null    object
# ...

# %%
smr = ['Size/ details of Infrastructure','Built under Scheme','Details of number of Coaches available for the sport','Sl. No.','Unnamed: 3','Unnamed: 4','Owned by Institution (State Govt./ SAI/Private)','Unnamed: 5','Unnamed: 10','Unnamed: 11']

# %%
sat = data.drop(smr,inplace =True,axis =1)

# %%
data.head()
# Out:
#   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 0                                                NaN
# 1                            Sri Kanteerava Stadium
# 2                         Koramangala Indoor Stadium
# 3                                       Vidyanagara
# 4                                             Anekal
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.

# %%
data.columns
# Out:
# Index(['Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)', 'Location of the Infrastructure (Tehsil/ Taluk and District)'], dtype='object')

# %%
data.tail()
# Out:
#     Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 167                                        Muddebihala
# 168                                            Sindagi
# 169                          Yadagiri district stadium
# 170                                          Shahapura
# 171                                       Gurumithakal
#
#     Location of the Infrastructure (Tehsil/ Taluk and District)
# 167                   Muddebihal, Vijayapura District.
# 168                      Sindagi, Vijayapura District.
# 169                                          Yadagiri.
# 170                      Shahapura, Yadagiri District.
# 171                    Gurumitkal, Yadagiri District.

# %%
data['Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)'].value_counts()
# Out:
# Sri Kanteerava Stadium        1
# Mandya District Stadium       1
# Maluru                        1
# Mulubagilu                    1
# Srinivaspura                  1
#                              ..
# Holalkere                     1
# Mangalore District Satdium    1
# Beltangadi                    1
# Mudubidre                     1
# Gurumithakal                  1
# Name: Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise), Length: 171, dtype: int64

# %%
data.dtypes
# Out:
# Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)    object
# Location of the Infrastructure (Tehsil/ Taluk and District)                                       object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 2 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  171 non-null    object
#  1   Location of the Infrastructure (Tehsil/ Taluk and District)                                     171 non-null    object
# dtypes: object(2)
# memory usage: 2.8+ KB

# %%
data['Location of the Infrastructure (Tehsil/ Taluk and District)'].value_counts()
# Out:
# Dharawad Distrct.                     5
# Bangalore                             3
# Ramanagara                            2
# Shivamogga                            2
# Hosadurga, Chitradurga.               2
#                                      ..
# Sulya, Dakshina Kannada District.     1
# Davanagere                            1
# Davanagere District.                  1
# Channagiri, Davanagere District.      1
# Gurumitkal, Yadagiri District.        1
# Name: Location of the Infrastructure (Tehsil/ Taluk and District), Length: 156, dtype: int64

# %%
data.head()
# Out:
#   Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)  \
# 0                                                NaN
# 1                            Sri Kanteerava Stadium
# 2                         Koramangala Indoor Stadium
# 3                                       Vidyanagara
# 4                                             Anekal
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.

# %%
data.rename(columns={'Infrastructure available (Stadium, Hall, Swimming Pools and other such facilities Sports-wise)' : 'address_line_1', 'Unnamed: 5' :'Address' }, inplace=True)

# %%
data.head()
# Out:
#                address_line_1  \
# 0                         NaN
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.

# %%
data.insert(loc=0, column= 'Name',  value='Department of Youth Empowerment and Sports, Karnataka',  allow_duplicates=True)

# %%
data.head()
# Out:
#                                                 Name  \
# 0  Department of Youth Empowerment and Sports, Ka...
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1  \
# 0                         NaN
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.

# %%
data.drop(index =0, inplace =True)

# %%
data.head()
# Out:
#                                                 Name  \
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
# 5  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1  \
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
# 5     Honnigaanahatti (South)
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
# 5        Yalahanka Taluk, Bangalore Urban District.

# %%
data.insert(loc=3, column= 'manager_contact_no',  value='01123384782',  allow_duplicates=True)

# %%
data.head()
# Out:
#                                                 Name  \
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
# 5  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1  \
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
# 5     Honnigaanahatti (South)
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
# 5        Yalahanka Taluk, Bangalore Urban District.
#
#   manager_contact_no
# 1        01123384782
# 2        01123384782
# 3        01123384782
# 4        01123384782
# ...

# %%
data.insert(loc=3, column= 'name_of_manager',  value='Shri Anurag Singh Thakur',  allow_duplicates=True)

# %%
data.head()
# Out:
#                                                 Name  \
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
# 5  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1  \
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
# 5     Honnigaanahatti (South)
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
# 5        Yalahanka Taluk, Bangalore Urban District.
#
#             name_of_manager manager_contact_no
# 1  Shri Anurag Singh Thakur        01123384782
# ...

# %%
data.insert(loc=3, column= 'sub_ownership_id',  value='Karnataka',  allow_duplicates=True)

# %%
data.head()
# Out:
#                                                 Name  \
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
# 5  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1  \
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
# 5     Honnigaanahatti (South)
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
# 5        Yalahanka Taluk, Bangalore Urban District.
#
#   sub_ownership_id           name_of_manager manager_contact_no
# ...

# %%
data.insert(loc=2, column= 'state_id',  value='15',  allow_duplicates=True)

# %%
data.head()
# Out:
#                                                 Name  \
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
# 5  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1 state_id  \
# 1     Sri Kanteerava Stadium        15
# 2  Koramangala Indoor Stadium       15
# 3                Vidyanagara        15
# 4                      Anekal       15
# 5     Honnigaanahatti (South)       15
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
# 5        Yalahanka Taluk, Bangalore Urban District.
#
#   sub_ownership_id           name_of_manager manager_contact_no
# ...

# %%
data.insert(loc=0, column= 'state_id',  value='15',  allow_duplicates=True)

# %%
pincode = pd.read_excel('/content/pin_code.xlsx')

# %%
pincode.head()
# Out:
#    id  district_id  pincode
# 0   1            1   744201
# 1   2            1   744202
# 2   3            2   744302
# 3   4            2   744303
# 4   5            3   744105

# %%
create =['id','district_id']

# %%
pincode.drop(create, axis =1, inplace =True)

# %%
pincode.head()
# Out:
#    pincode
# 0   744201
# 1   744202
# 2   744302
# 3   744303
# 4   744105

# %%
pincode.shape
# Out:
# (19337, 1)

# %%
sru =pd.concat([data, pincode], axis=1)

# %%
sru.head()
# Out:
#   state_id                                               Name  \
# 0      NaN                                                NaN
# 1       15  Department of Youth Empowerment and Sports, Ka...
# 2       15  Department of Youth Empowerment and Sports, Ka...
# 3       15  Department of Youth Empowerment and Sports, Ka...
# 4       15  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1 state_id  \
# 0                         NaN      NaN
# 1     Sri Kanteerava Stadium        15
# 2  Koramangala Indoor Stadium       15
# 3                Vidyanagara        15
# 4                      Anekal       15
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 0                                                NaN
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
#
# ...

# %%
sru.tail()
# Out:
#       state_id Name address_line_1 state_id  \
# 19332      NaN  NaN            NaN      NaN
# 19333      NaN  NaN            NaN      NaN
# 19334      NaN  NaN            NaN      NaN
# 19335      NaN  NaN            NaN      NaN
# 19336      NaN  NaN            NaN      NaN
#
#       Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 19332                                                NaN
# 19333                                                NaN
# 19334                                                NaN
# 19335                                                NaN
# 19336                                                NaN
#
#       sub_ownership_id name_of_manager manager_contact_no  pincode
# 19332              NaN             NaN                NaN   835301
# 19333              NaN             NaN                NaN   835213
# 19334              NaN             NaN                NaN   835203
# 19335              NaN             NaN                NaN   835231
# ...

# %%
sru.dropna(inplace = True)

# %%
sru.head(2)
# Out:
#   state_id                                               Name  \
# 1       15  Department of Youth Empowerment and Sports, Ka...
# 2       15  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1 state_id  \
# 1     Sri Kanteerava Stadium        15
# 2  Koramangala Indoor Stadium       15
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
#
#   sub_ownership_id           name_of_manager manager_contact_no  pincode
# 1        Karnataka  Shri Anurag Singh Thakur        01123384782   744202
# 2        Karnataka  Shri Anurag Singh Thakur        01123384782   744302

# %%
sru.tail(1)
# Out:
#     state_id                                               Name  \
# 171       15  Department of Youth Empowerment and Sports, Ka...
#
#     address_line_1 state_id  \
# 171   Gurumithakal       15
#
#     Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 171                    Gurumitkal, Yadagiri District.
#
#     sub_ownership_id           name_of_manager manager_contact_no  pincode
# 171        Karnataka  Shri Anurag Singh Thakur        01123384782   524366

# %%
new_data = pd.read_excel('/content/district.xlsx')

# %%
new_data.head()
# Out:
#     id state_id             district_name
# 0  1.0        1  North And Middle Andaman
# 1  2.0        1                  Nicobars
# 2  3.0        1            South Andamans
# 3  4.0        2                 Anantapur
# 4  5.0        2             West Godavari

# %%
dele = ['id','state_id']

# %%
new_data.drop(dele,axis =1, inplace =True)

# %%
new_data.head(2)
# Out:
#               district_name
# 0  North And Middle Andaman
# 1                  Nicobars

# %%
sru =pd.concat([data, pincode,new_data], axis=1)

# %%
tum =sru.dropna(inplace = True)

# %%
sru.head(2)
# Out:
#   state_id                                               Name  \
# 1       15  Department of Youth Empowerment and Sports, Ka...
# 2       15  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1 state_id  \
# 1     Sri Kanteerava Stadium        15
# 2  Koramangala Indoor Stadium       15
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
#
#   sub_ownership_id           name_of_manager manager_contact_no  pincode  \
# 1        Karnataka  Shri Anurag Singh Thakur        01123384782   744202
# 2        Karnataka  Shri Anurag Singh Thakur        01123384782   744302
#
#     district_name
# 1        Nicobars
# 2  South Andamans

# %%
sru.tail(2)
# Out:
#     state_id                                               Name  \
# 170       15  Department of Youth Empowerment and Sports, Ka...
# 171       15  Department of Youth Empowerment and Sports, Ka...
#
#     address_line_1 state_id  \
# 170      Shahapura       15
# 171   Gurumithakal       15
#
#     Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 170                      Shahapura, Yadagiri District.
# 171                    Gurumitkal, Yadagiri District.
#
#     sub_ownership_id           name_of_manager manager_contact_no  pincode  \
# 170        Karnataka  Shri Anurag Singh Thakur        01123384782   524313
# 171        Karnataka  Shri Anurag Singh Thakur        01123384782   524366
#
#     district_name
# 170   Gir Somnath
# 171     Porbandar

# %%
sru.drop(sru.columns[[3]],axis =1, inplace =True)

# %%
sru.head()
# Out:
#                                                 Name  \
# 1  Department of Youth Empowerment and Sports, Ka...
# 2  Department of Youth Empowerment and Sports, Ka...
# 3  Department of Youth Empowerment and Sports, Ka...
# 4  Department of Youth Empowerment and Sports, Ka...
# 5  Department of Youth Empowerment and Sports, Ka...
#
#                address_line_1  \
# 1     Sri Kanteerava Stadium
# 2  Koramangala Indoor Stadium
# 3                Vidyanagara
# 4                      Anekal
# 5     Honnigaanahatti (South)
#
#   Location of the Infrastructure (Tehsil/ Taluk and District)  \
# 1                                          Bangalore
# 2                                          Bangalore
# 3                                          Bangalore
# 4           Anekal Taluk, Bangalore Urban District.
# 5        Yalahanka Taluk, Bangalore Urban District.
#
#             name_of_manager manager_contact_no  pincode   district_name
# ...

# %%
name = sagar
